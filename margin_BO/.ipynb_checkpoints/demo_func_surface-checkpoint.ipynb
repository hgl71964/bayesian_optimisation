# %%
import numpy as np
import matplotlib.pyplot as plt
import copy
import torch

# import scripts
from scripts.transformation import transformer
from scripts.transformation import fake_api
from scripts.transformation import api_utils
from scripts.function_slicer import slicer

dtype = torch.float

# %% [markdown]
# ##### visualisation

# %%
scr = slicer(8)
slices = scr.load_data(folder_name = "func_surface", save_name = "July 17, dim = (4,5)")
len(slices)
# Out:
# 4

# %%
scr.plot(slices, 3, np.arange(.99, 2.0,0.01))

# %%
scr.plot(slices, 1, np.arange(.8, 1.1,0.05))

# %%
slices = scr.load_data(folder_name = "func_surface", save_name = "July 30 random1, dim = (6,7)")
scr.plot_4_figs(slices,  np.arange(.8, 1.3,0.02))

# %%
slices = scr.load_data(folder_name = "func_surface", save_name = "July 30 random2, dim = (6,7)")
scr.plot_4_figs(slices,  np.arange(.8, 1.3,0.02))

# %%
slices = scr.load_data(folder_name = "func_surface", save_name = "July 16, dim = (4,5)")

scr.plot_4_figs(slices,  np.arange(.8, 1.1,0.05))
