# %%
import sys
sys.path.insert(0,r"/usr/local/lib/python3.7/site-packages")
sys.path.insert(0,r"/Users/guoliang/Library/Python/3.7/lib/python/site-packages")
import numpy as np
import matplotlib.pyplot as plt
import copy
import torch

# import scripts
from scripts.api_helper import transformer
from scripts.api_helper import fake_api
from scripts.api_helper import api_utils
from scripts.function_slicer import slicer

dtype = torch.float

# %% [markdown]
# ##### visualisation

# %%
scr = slicer(8)
slices = scr.load_data(folder_name = "func_surface", save_name = "July 17, dim = (0,1)")
len(slices)
# Out:
# 4

# %%
scr.plot(slices, 3, np.arange(.8, 1.2,0.01))

# %%
scr.plot(slices, 1, np.arange(.8, 1.1,0.05))

# %%
slices = scr.load_data(folder_name = "func_surface", save_name = "July 30 random1, dim = (4,5)")
scr.plot_4_figs(slices,  np.arange(.8, 1.3,0.02))

# %%
slices = scr.load_data(folder_name = "func_surface", save_name = "July 30 random2, dim = (4,5)")
scr.plot_4_figs(slices,  np.arange(.8, 1.3,0.02))

# %%
slices = scr.load_data(folder_name = "func_surface", save_name = "July 17, dim = (4,5)")

scr.plot_4_figs(slices,  np.arange(.8, 1.1,0.05))
